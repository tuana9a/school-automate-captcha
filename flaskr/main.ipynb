# %%
import matplotlib.pyplot as plt
from PIL import Image

from vietocr.tool.predictor import Predictor
from vietocr.tool.config import Cfg

def load_model(weith_path, device):
    config = Cfg.load_config_from_name('vgg_transformer')
    config['weights'] = weith_path
    config['cnn']['pretrained'] = False
    config['device'] = device
    config['predictor']['beamsearch'] = False
    model = Predictor(config)
    return model

# %%
model = load_model('./models/weights.pth', 'cpu')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-7216373e8cd1> in <module>
# ----> 1 model = load_model('./models/weights.pth', 'cpu')
#
# <ipython-input-1-36919926ea0a> in load_model(weith_path, device)
#      11     config['device'] = device
#      12     config['predictor']['beamsearch'] = False
# ---> 13     model = Predictor(config)
#      14     return model
#
# d:\GemDino\Project\school-automate\automate-worker-captcha\venv\lib\site-packages\vietocr\tool\predictor.py in __init__(self, config)
#      17             weights = config['weights']
#      18
# ---> 19         model.load_state_dict(torch.load(weights, map_location=torch.device(device)))
#      20
#      21         self.config = config
#
# d:\GemDino\Project\school-automate\automate-worker-captcha\venv\lib\site-packages\torch\serialization.py in load(f, map_location, pickle_module, **pickle_load_args)
#     579         pickle_load_args['encoding'] = 'utf-8'
#     580
# --> 581     with _open_file_like(f, 'rb') as opened_file:
#     582         if _is_zipfile(opened_file):
#     583             # The zipfile reader is going to advance the current file position.
#
# d:\GemDino\Project\school-automate\automate-worker-captcha\venv\lib\site-packages\torch\serialization.py in _open_file_like(name_or_buffer, mode)
#     228 def _open_file_like(name_or_buffer, mode):
#     229     if _is_path(name_or_buffer):
# --> 230         return _open_file(name_or_buffer, mode)
#     231     else:
#     232         if 'w' in mode:
#
# d:\GemDino\Project\school-automate\automate-worker-captcha\venv\lib\site-packages\torch\serialization.py in __init__(self, name, mode)
#     209 class _open_file(_opener):
#     210     def __init__(self, name, mode):
# --> 211         super(_open_file, self).__init__(open(name, mode))
#     212
#     213     def __exit__(self, *args):
#
# FileNotFoundError: [Errno 2] No such file or directory: './models/weights.pth'

# %%
img_path = './models/test/test5.png'
img = Image.open(img_path)
result = model.predict(img)
print(result)
# plt.imshow(img)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-e19c4b700198> in <module>
#       1 img_path = './models/test/test5.png'
# ----> 2 img = Image.open(img_path)
#       3 result = model.predict(img)
#       4 print(result)
#       5 plt.imshow(img)
#
# NameError: name 'Image' is not defined

# %%
print("hello world")
# Out:
# hello world
